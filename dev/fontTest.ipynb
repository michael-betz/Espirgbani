# %%
# %pylab notebook
import matplotlib.image as mpimg
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ```C
# if( isOutline ){
#     shade = shade > 127 ? 255 : 2*shade;
# } else {
#     shade = shade > 127 ? 2*shade-255 : 0;
# }
# ```

# %%
img = mpimg.imread("./fonts/out/15_0.bmp")[:60,:,:]
print( img.shape )
imshow( img[:,:,1], vmin=0, vmax=255, cmap=matplotlib.cm.gray )
# Out:
# (60, 50, 4)
# <img src="data:image/png;base64,..." width="640">

# %%
inds = img<=127
oImg = ones_like( img ) * 255
oImg[ inds ] = img[ inds ]*2
inds = img>127
iImg = ones_like( img ) * 0
iImg[ inds ] = img[ inds ]*2-255

# %%
close("all")
imshow( stack( (oImg, zeros_like(img), iImg), 2 ) )
# Out:
# <img src="data:image/png;base64,..." width="640">
